# %%
import numpy as np
import pandas as pd


colors = pd.Series(["Red","Blue","White"])
print(colors)
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
cars_data = pd.DataFrame(
   { "carmake":colors}
)

cars_data
# Out:
#   carmake
# 0     Red
# 1    Blue
# 2   White

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car_sales.csv",index=False)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
pd.crosstab(car_sales["Colour"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Colour
# Black   0  0  1
# Blue    1  2  0
# Green   0  1  0
# Red     0  1  0
# White   0  4  0

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
water = "hhhhhhhhHHHHHHHHHHHH"
water.lower()
# Out:
# 'hhhhhhhhhhhhhhhhhhhh'

# %%
car_sales
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]","")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_82340\2951068123.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]","")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hp\Desktop\zero\car_sales\car_sales.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/zero/car_sales/car_sales.ipynb#ch0000014?line=0'>1</a> car_sales["Price"].dtypes  = car_sales.astype({'Price': 'int64'}).dtypes
#
# File c:\Users\hp\anaconda3\lib\site-packages\pandas\core\generic.py:5870, in NDFrame.astype(self, dtype, copy, errors)
#    <a href='file:///c%3A/Users/hp/anaconda3/lib/site-packages/pandas/core/generic.py?line=5867'>5868</a> if self.ndim == 1:  # i.e. Series
#    <a href='file:///c%3A/Users/hp/anaconda3/lib/site-packages/pandas/core/generic.py?line=5868'>5869</a>     if len(dtype) > 1 or self.name not in dtype:
# -> <a href='file:///c%3A/Users/hp/anaconda3/lib/site-packages/pandas/core/generic.py?line=5869'>5870</a>         raise KeyError(
# ...

# %%
# car_sales["Price"].astype(int)
car_sales.Price.astype(int)
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales["Num. of Wheels"]= 4

# %%
car_sales_sample = car_sales.sample(frac=1)
car_sales_sample
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Num. of Wheels
# 1   Honda    Red          87899      4   500000               4
# 7   Honda   Blue          54738      4   700000               4
# 3     BMW  Black          11179      5  2200000               4
# 4  Nissan  White         213095      4   350000               4
# 6   Honda   Blue          45698      4   750000               4
# 0  Toyota  White         150043      4   400000               4
# 9  Nissan  White          31600      4   970000               4
# 2  Toyota   Blue          32549      3   700000               4
# 8  Toyota  White          60000      4   625000               4
# 5  Toyota  Green          99213      4   450000               4

# %%
car_sales_sample.reset_index()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Num. of Wheels
# 0   Honda    Red          87899      4   500000               4
# 1   Honda   Blue          54738      4   700000               4
# 2     BMW  Black          11179      5  2200000               4
# 3  Nissan  White         213095      4   350000               4
# 4   Honda   Blue          45698      4   750000               4
# 5  Toyota  White         150043      4   400000               4
# 6  Nissan  White          31600      4   970000               4
# 7  Toyota   Blue          32549      3   700000               4
# 8  Toyota  White          60000      4   625000               4
# 9  Toyota  Green          99213      4   450000               4

# %%
car_sales["Odometer (KM)"]  = car_sales["Odometer (KM)"] *  0.621371
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Num. of Wheels
# 0  Toyota  White         150043      4   400000               4
# 1   Honda    Red          87899      4   500000               4
# 2  Toyota   Blue          32549      3   700000               4
# 3     BMW  Black          11179      5  2200000               4
# 4  Nissan  White         213095      4   350000               4
# 5  Toyota  Green          99213      4   450000               4
# 6   Honda   Blue          45698      4   750000               4
# 7   Honda   Blue          54738      4   700000               4
# 8  Toyota  White          60000      4   625000               4
# 9  Nissan  White          31600      4   970000               4

# %%
car_sales["Odometer (KM)"]  = car_sales["Odometer (KM)"] *  0.621371

# %%
car_sales["Odometer (KM)"]
# Out:
# 0     93232.368953
# 1     54617.889529
# 2     20225.004679
# 3      6946.306409
# 4    132411.053245
# 5     61648.081023
# 6     28395.411958
# 7     34012.605798
# 8     37282.260000
# 9     19635.323600
# Name: Odometer (KM), dtype: float64

# %%
odometer_sorted =car_sales["Odometer (KM)"].sort_values( ascending=True)

odometer_sorted.tail()
# Out:
# 8     37282.260000
# 1     54617.889529
# 5     61648.081023
# 0     93232.368953
# 4    132411.053245
# Name: Odometer (KM), dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt(i) for i in x_vals]
fig , ax = plt.subplots()

ax.plot(x_vals, y_vals)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips_df = sns.load_dataset("tips")
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
X = tips_df.drop(tips_df.columns[[1 ]], axis=1)

# %%
X
# Out:
#      total_bill     sex smoker   day    time  size
# 0         16.99  Female     No   Sun  Dinner     2
# 1         10.34    Male     No   Sun  Dinner     3
# 2         21.01    Male     No   Sun  Dinner     3
# 3         23.68    Male     No   Sun  Dinner     2
# 4         24.59  Female     No   Sun  Dinner     4
# ..          ...     ...    ...   ...     ...   ...
# 239       29.03    Male     No   Sat  Dinner     3
# 240       27.18  Female    Yes   Sat  Dinner     2
# 241       22.67    Male    Yes   Sat  Dinner     2
# 242       17.82    Male     No   Sat  Dinner     2
# 243       18.78  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
X = tips_df.drop(tips_df.columns[1 ], axis=1)

# %%
X
# Out:
#      total_bill     sex smoker   day    time  size
# 0         16.99  Female     No   Sun  Dinner     2
# 1         10.34    Male     No   Sun  Dinner     3
# 2         21.01    Male     No   Sun  Dinner     3
# 3         23.68    Male     No   Sun  Dinner     2
# 4         24.59  Female     No   Sun  Dinner     4
# ..          ...     ...    ...   ...     ...   ...
# 239       29.03    Male     No   Sat  Dinner     3
# 240       27.18  Female    Yes   Sat  Dinner     2
# 241       22.67    Male    Yes   Sat  Dinner     2
# 242       17.82    Male     No   Sat  Dinner     2
# 243       18.78  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips_df[["sex", "smoker" , "day" , "time" ]]  # categorical = X.filter([‘sex’ , ‘smoker’ , ‘day’ , ‘time’ ])
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]
